# %% [markdown]
# # NumPy Practice
#
# 本 Notebook 用于练习 NumPy 的基础操作。
#
# 本次练习内容包括：
#
# 1. 创建数组；
# 2. 查看 shape 和 dtype；
# 3. reshape 改变数组形状；
# 4. 索引和切片；
# 5. 广播机制；
# 6. 矩阵乘法；
# 7. 常用统计函数；
# 8. 简单模拟训练 loss 数据。

# %%
import numpy as np

print("NumPy version:", np.__version__)

# %%
# 从 Python 列表创建 NumPy 数组
a = np.array([1, 2, 3, 4, 5])

print(a)
print(type(a))

# %%
zeros = np.zeros((3, 4))
ones = np.ones((2, 3))
random_array = np.random.randn(4, 5)

print("zeros:")
print(zeros)

print("ones:")
print(ones)

print("random_array:")
print(random_array)

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])

print("x:")
print(x)

print("shape:", x.shape)
print("dtype:", x.dtype)
print("维度数量:", x.ndim)

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])

print("x:")
print(x)

print("shape:", x.shape)
print("dtype:", x.dtype)
print("维度数量:", x.ndim)

# %%
x = np.arange(12)

print("原始 x:")
print(x)
print("原始 shape:", x.shape)

x_reshaped = x.reshape(3, 4)

print("reshape 之后:")
print(x_reshaped)
print("新的 shape:", x_reshaped.shape)

# %%
x = np.arange(12).reshape(3, 4)

print("x:")
print(x)

print("第 0 行:")
print(x[0])

print("第 1 列:")
print(x[:, 1])

print("前两行，前两列:")
print(x[:2, :2])

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])

print("原始 x:")
print(x)

print("x + 10:")
print(x + 10)

y = np.array([10, 20, 30])

print("x + y:")
print(x + y)

# %%
A = np.random.randn(3, 4)
B = np.random.randn(4, 2)

C = A @ B

print("A shape:", A.shape)
print("B shape:", B.shape)
print("C shape:", C.shape)

print("C:")
print(C)

# %%
data = np.random.randn(100)

print("均值 mean:", data.mean())
print("标准差 std:", data.std())
print("最大值 max:", data.max())
print("最小值 min:", data.min())
print("中位数 median:", np.median(data))

# %%
scores = np.array([60, 70, 80, 90, 100])

normalized_scores = (scores - scores.min()) / (scores.max() - scores.min())

print("原始分数:")
print(scores)

print("归一化之后:")
print(normalized_scores)

# %%
epochs = np.arange(1, 11)
loss = np.exp(-epochs / 3) + np.random.randn(10) * 0.02

print("epochs:")
print(epochs)

print("loss:")
print(loss)

# %% [markdown]
# ## NumPy 总结
#
# 本节练习了 NumPy 的基础操作。
#
# 需要重点掌握：
#
# - `np.array()` 用于创建数组；
# - `shape` 表示数组形状；
# - `reshape()` 用于改变数组形状；
# - 索引和切片可以取出数组中的部分数据；
# - 广播机制可以让不同形状的数组进行运算；
# - `@` 可以进行矩阵乘法；
# - `mean()`、`std()`、`max()`、`min()` 是常用统计函数。
#
# 这些内容后面学习 PyTorch Tensor 时会继续用到。
